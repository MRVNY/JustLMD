# %% [markdown]
# # Data from EDGE

# %%
import pickle

with open('test_1sqE6P3XyiQ.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
print(data.keys())
# Out:
# dict_keys(['smpl_poses', 'smpl_trans', 'full_pose'])

# %%
print(data['full_pose'].shape)
# Out:
# (900, 24, 3)

# %%
print(data['smpl_poses'].shape)
# Out:
# (900, 72)

# %%
print(data['smpl_trans'].shape)
# Out:
# (900, 3)

# %%
full_flat = data['full_pose'][0].reshape(-1)
print(full_flat)
print(full_flat.shape)
# Out:
# [-0.04497426 -0.1598381   1.9851645  -0.01824823 -0.14282826  1.8876443
#  -0.1311971  -0.16633366  1.9178091  -0.01033549 -0.10720745  2.09918
#   0.06101736 -0.16410057  1.5074131  -0.35023385 -0.4751035   1.8416833
#  -0.00618799 -0.14630516  2.2341824   0.11319463 -0.10033762  1.086636
#  -0.29268992 -0.28378493  1.4700896  -0.01128403 -0.16373265  2.2873163
#   0.18528175 -0.20906137  1.0300957  -0.27505255 -0.3863455   1.3641398
#  -0.02034589 -0.2311441   2.4909399   0.06269328 -0.19697465  2.3964796
#  -0.09202181 -0.19650143  2.3991241   0.0048347  -0.30983832  2.5519843
#   0.16832668 -0.27576083  2.384222   -0.2033284  -0.24750765  2.4089663
#   0.06756757 -0.45334083  2.2284057  -0.299973   -0.4068712   2.2242677
#  -0.14291826 -0.48848414  2.3873954  -0.15451431 -0.60978496  2.325112
#  -0.22322845 -0.50105864  2.422944   -0.10478812 -0.6814429   2.3462467 ]
# (72,)

# %%
print(data['smpl_poses'][0])
print(data['smpl_poses'][0].shape)
# Out:
# [ 1.4627860e+00  3.8018176e-01 -1.1081575e-01 -3.3013884e-03
#  -2.7146213e-02  4.0350017e-01 -7.7663589e-01  1.6308969e-01
#  -6.7854983e-01  1.6418512e-01 -6.7274168e-02  3.5335726e-01
#   1.0670255e-01  6.9751870e-03  1.0039486e-01  1.0326130e+00
#  -6.9560863e-02  1.3153013e+00  1.6703227e-01 -4.8865948e-02
#   4.4906542e-02 -2.4273146e-03  6.6728634e-03 -1.0498582e-02
#  -1.7593383e-03 -5.5877017e-03 -3.0356597e-03  2.1391521e-01
#  -3.4555793e-02 -6.8984874e-02  6.4122062e-03  1.2580337e-02
#   9.0774288e-03  1.7244414e-03  3.0068895e-03  1.1766275e-02
#  -7.1547225e-02  8.9205094e-02 -8.7753035e-02 -1.5635428e-01
#  -8.4968108e-01 -1.8565929e-01 -1.9503151e-01  4.7160563e-01
#   1.7624775e-01 -2.7781308e-01  7.3520072e-02 -1.1089881e-01
#  -8.7655216e-02 -1.0991876e+00 -4.3030229e-01 -1.3658102e-01
#   6.3576370e-01  3.8965169e-01 -2.1779688e-02 -1.4469985e+00
#   1.5906453e-01 -3.7949447e-02  1.4044408e+00 -3.9970040e-01
# ...

# %% [markdown]
# # Data from EasyMocap

# %%
import json
import numpy as np

full = json.load(open('000000_full.json', 'r'))
smpl = json.load(open('000000_smpl.json', 'r'))

# %%
print(np.array(full['annots'][0]['poses'][0]))
print(np.array(full['annots'][0]['poses'][0]).shape)
# Out:
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00