# %%
! python -m src.train.train_cvae

# %%
! python -m src.visualize.visualize_checkpoint exps/saved/checkpoint_5000.pth.tar --num_actions_to_sample 5  --num_samples_per_action 5
# Out:
# Restore weights..
# Visualization of the epoch 5000
# Traceback (most recent call last):
#   File "/home/yiyu/miniconda3/lib/python3.8/runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/yiyu/miniconda3/lib/python3.8/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/yiyu/JustLM2D/ACTOR/src/visualize/visualize_checkpoint.py", line 32, in <module>
#     main()
#   File "/home/yiyu/JustLM2D/ACTOR/src/visualize/visualize_checkpoint.py", line 28, in main
#     viz_epoch(model, dataset, epoch, parameters, folder=folder, writer=None)
#   File "/home/yiyu/JustLM2D/ACTOR/src/visualize/visualize.py", line 135, in viz_epoch
#     meandurations = torch.from_numpy(np.array([round(dataset.get_mean_length_label(cl.item()))
#   File "/home/yiyu/JustLM2D/ACTOR/src/visualize/visualize.py", line 135, in <listcomp>
#     meandurations = torch.from_numpy(np.array([round(dataset.get_mean_length_label(cl.item()))
# ...

# %%
# %cd ../Pipeline/.EasyMocap
! python scripts/postprocess/convert2bvh.py -- /home/yiyu/JustLM2D/ACTOR/frames --out /home/yiyu/JustLM2D/ACTOR
# %cd ..
# Out:
# /home/yiyu/JustLM2D/Pipeline/.EasyMocap
# Traceback (most recent call last):
#   File "scripts/postprocess/convert2bvh.py", line 9, in <module>
#     import bpy
# ModuleNotFoundError: No module named 'bpy'
# /home/yiyu/JustLM2D/Pipeline
