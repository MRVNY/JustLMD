# %%
! python -m src.train.train_cvae

# %%
! python -m src.visualize.visualize_checkpoint /Users/Marvin/NII_Code/JustLM2D/ACTOR/exps/saved/checkpoint_5000.pth.tar --num_actions_to_sample 5  --num_samples_per_action 5
