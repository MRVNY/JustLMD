# %%
! python -m src.train.train_cvae

# %%
# %cd ../Pipeline/.EasyMocap
! python scripts/postprocess/convert2bvh.py -- /home/yiyu/JustLM2D/ACTOR/frames --out /home/yiyu/JustLM2D/ACTOR
# %cd ..
# Out:
# Traceback (most recent call last):
#   File "/Users/Marvin/miniconda3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/Marvin/miniconda3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/Marvin/NII_Code/JustLM2D/ACTOR/src/visualize/visualize_checkpoint.py", line 31, in <module>
#     main()
#   File "/Users/Marvin/NII_Code/JustLM2D/ACTOR/src/visualize/visualize_checkpoint.py", line 18, in main
#     model, datasets = get_model_and_data(parameters)
#   File "/Users/Marvin/NII_Code/JustLM2D/ACTOR/src/utils/get_model_and_data.py", line 12, in get_model_and_data
#     LMD_Dict = torch.load('/home/yiyu/JustLM2D/Pipeline/JD20-22_LMD_Dict_20230602192541.pth')
#   File "/Users/Marvin/miniconda3/lib/python3.10/site-packages/torch/serialization.py", line 771, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/Users/Marvin/miniconda3/lib/python3.10/site-packages/torch/serialization.py", line 270, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/Users/Marvin/miniconda3/lib/python3.10/site-packages/torch/serialization.py", line 251, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yiyu/JustLM2D/Pipeline/JD20-22_LMD_Dict_20230602192541.pth'

# %%
# %cd ../Pipeline/.EasyMocap
! python scripts/postprocess/convert2bvh.py -- /Users/Marvin/NII_Code/JustLM2D/ACTOR/frames --out /Users/Marvin/NII_Code/JustLM2D/ACTOR/
# %cd ..
# Out:
# /Users/Marvin/NII_Code/JustLM2D/Pipeline/.EasyMocap
# {'path': '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames', 'out': '/Users/Marvin/NII_Code/JustLM2D/ACTOR/', 'smpl_data_folder': './data/smplx/SMPL_maya', 'gender': 'male'}
# FBX version: 7400
# success load
# ['/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000000.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000001.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000002.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000003.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000004.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000005.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000006.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000007.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000008.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000009.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000010.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000011.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000012.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000013.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000014.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000015.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000016.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000017.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000018.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000019.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000020.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000021.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000022.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000023.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000024.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000025.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000026.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000027.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000028.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000029.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000030.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000031.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000032.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000033.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000034.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000035.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000036.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000037.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000038.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000039.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000040.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000041.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000042.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000043.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000044.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000045.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000046.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000047.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000048.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000049.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000050.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000051.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000052.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000053.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000054.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000055.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000056.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000057.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000058.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000059.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000060.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000061.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000062.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000063.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000064.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/frames/000065.json', '/Users/Marvin/NII_Code/JustLM2D/ACTOR/ ...
# /Users/Marvin/NII_Code/JustLM2D/Pipeline/.EasyMocap/scripts/postprocess/convert2bvh.py:152: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mat = np.asarray([[0, -r[2], r[1]],
# BVH Exported: /Users/Marvin/NII_Code/JustLM2D/ACTOR/0.bvh frames:180
#
# Done!
# /Users/Marvin/NII_Code/JustLM2D/Pipeline
